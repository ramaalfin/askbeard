# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### 1. Import Data, Data Cleaning
# - **File csv**

# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### Data preparation
# - 1. import

# %%
#import Library
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
#read file csv
df = pd.read_csv("cars_data.csv")

#replace nan -> 0
# df['normalized-losses'] = df['normalized-losses'].replace(np.nan, 0)
# df.head()

#replace nan -> average values pada kolom normalized-losses
# df['normalized-losses'] = df['normalized-losses'].replace(np.nan, df['normalized-losses'].mean())
# df.head()

#drop/hapus rows yang mengandung missing values di kolom normalized-losses
df = df.dropna(subset=['normalized-losses'], axis=0)
df.head()
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2              164.0  audi       gas        std         four
# 4          2              164.0  audi       gas        std         four
# 6          1              158.0  audi       gas        std         four
# 8          1              158.0  audi       gas      turbo         four
# 9          2              192.0   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# 8      sedan          fwd           front       105.8  ...          131
# 9      sedan          rwd           front       101.2  ...          108
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
df_mobil.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eb553e7514ac> in <module>
# ----> 1 df_mobil.columns
#
# NameError: name 'df_mobil' is not defined

# %% [markdown]
# <br>
# Data Cleaning

# %%
#data cleaning
#replace nan -> 0
df['normalized-losses'] = df['normalized-losses'].replace(np.nan, 0)
df.head(1)

# %%
df_mobil['normalized-losses'] = df_mobil['normalized-losses'].replace(np.nan, 0)

# %%
#data cleaning
#replace nan -> average values pada kolom normalized-losses
df['normalized-losses'] = df['normalized-losses'].replace(np.nan, df['normalized-losses'].mean())
df.head(1)

# %%
#data cleaning
#drop rows yang mengandung missing values di kolom normalized-losses
df = df.dropna(subset = ['normalized-losses'], axis=0)
df.head()

# %%
df_mobil

# %% [markdown]
# <br>
# ##### Data Formatting

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cars_data.csv')
#Data formatting
#mengubah satuan miles per galon ke satuan L/100km pada kolom city-mpg
df['city-mpg'] = 235/df['city-mpg']
df = df.rename(columns = {'city-mpg':'city-L/KM'})
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_mobil['city-mpg'] = 235/df_mobil['city-mpg']

# %%
df_mobil.head()

# %%
df_mobil

# %%
df_mobil = df_mobil.rename(columns={'city-mpg': 'city-L/100km'})

# %%
#Data formatting
#rename city-mpg ke city-L/km
df = df.rename(columns={'city-mpg':'city-L/km'})
df.head()

# %%
import pandas as pd
df = pd.read_csv("cars_data.csv")

#Data formatting
#mengubah tipe data integer ke float
df['price'] = df['price'].astype('int')

df.head()
# df['price'].dtype
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_mobil['price'].dtype

# %%
df_mobil['price'] = df_mobil['price'].astype('int')

# %%
df_mobil.head(1)

# %%
df['price'] = df['price'].astype('float')
df['price'].dtype

# %%
df_mobil['price'].dtype

# %% [markdown]
# <br>
# ##### Data Normalization

# %%
import pandas as pd
df = pd.read_csv('cars_data.csv')

#Data Normaliszation
Headers = ['age', 'income']
data = [['15', 124000], ['20', 152000], ['23', 603000]]

df = pd.DataFrame(data, columns = Headers)
df
# df_KK['income'].min()
# df_KK['income'].max()

# #normalisasi data menggunakan simple feature scaling method
# df['income'] = (df['income'])/(df['income'].max())
# df

# #normalisasi data menggunakan min max method
df['income'] = (df['income']-df['income'].min())/(df['income'].max()-df['income'].min())
df

# #normalisasi data menggunakan z-score method
df['income'] = (df['income']-df['income'].mean())/df['income'].std()
df
# Out:
#   age    income
# 0  15 -0.628644
# 1  20 -0.524490
# 2  23  1.153134

# %%
df_KK['income'].min()

# %%
#normalisasi data menggunakan simple feature scaling method
df_KK['income'] = (df_KK['income'])/(df_KK['income'].max())
df_KK

# %%
#normalisasi data menggunakan min max method
df_KK['income'] = (df_KK['income']-df_KK['income'].min())/(df_KK['income'].max()-df_KK['income'].min())
df_KK

# %%
#normalisasi data menggunakan z-score method
df_KK['income'] = (df_KK['income']-df_KK['income'].mean())/df_KK['income'].std()
df_KK

# %% [markdown]
# ##### Binning

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cars_data.csv')

#binning data price
bins = np.linspace(min(df['price']), max(df['price']), 4)
df['price'] = pd.cut(df['price'], bins, labels=group_names, include_lowest=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1               95.0        volvo       gas        std
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
bins = np.linspace(min(df_mobil['price']), max(df_mobil['price']), 4)

# %%
bins

# %%
df_mobil['price_binned'] = pd.cut(df_mobil['price'], bins, labels=group_names, include_lowest=True)

# %%
df.head()

# %%
bins

# %%
#penggunaan include lowest = true untuk 
#pd.cut(pd.Series(range(101)), [0, 24, 49, 74, 100])
np.linspace(min(df['price']), max(df['price']),3)
a = df[fdajf] >= dfksf and kadf <=

# %%
df_mobil.to_csv('data_mobil_cleaned.csv')

# %% [markdown]
# <br>
#  # Data Visualization
#  - line plot
#  - area plot
#  - Bar plot
#  - Histogram plot
#  - Pie Chart
#  - Box plot
#  - Scatter plot
#  <br>
#  <br>
#  <br>
# **Kita coba rapihin datanya dulu.**

# %%
#data frame Imigrant Canada
df_can = pd.read_excel('Canada.xlsx',
                      sheet_name = "Canada by Citizenship",
                      skiprows = range(20),
                      skipfooter = 2)

df_can.head()

# Data Cleaning
# me rename kolom OdName
df_can = df_can.rename(columns={'OdName':'Country'})
df_can.head()

#set index berdasarkan country dan dataframe yg baru disimpan pada df_country
df_country = df_can.set_index('Country')
df_country.head()

# #check index location
df_country.iloc[0,8]

# membuat kolom total yang isinya adalah total imigrant dari tahun 1980-2013
df_country['Total'] = df_country.iloc[:, 8:].sum(axis = 1)
df_country.head(1)

#check tipe data setiap kolom pada dataframenya
df_country.columns.map(type)

#ubah tipe data setiap kolom pada dataframenya menjadi str semua
df_country.columns = df_country.columns.astype(str)

#check tipe data kolomnya lagi
df_country.columns.map(type)
# Out:
# Index([<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>],
#       dtype='object')

# %%
#Melihat 5 baris pertama isi dataframe canada
df_can.head()

# %%
#Data Cleaning
#rename kolom OdName -> Country
df_can = df_can.rename(columns={'OdName':'Country'})
df_can.head()

# %%
#set index berdasarkan country dan dataframe yg baru disimpan pada df_country
df_country = df_can.set_index('Country')
df_country.head(1)

# %%
#check index location
df_country.iloc[0,8]

# %%
# membuat kolom total yang isinya adalah total imigrant dari tahun 1980-2013
df_country['Total'] = df_country.iloc[:, 8:].sum(axis = 1)
df_country.head(1)

# %%
#check tipe data setiap kolom pada dataframenya
df_country.columns.map(type)

# %%
#ubah tipe data setiap kolom pada dataframenya menjadi str semua
df_country.columns = df_country.columns.astype(str)

# %%
#check tipe data kolomnya lagi
df_country.columns.map(type)

# %% [markdown]
# <br>
# **Setelah dataframe sudah rapi, kita buat visualisasi datanya**
# **menggunakan library matplotlib.**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
df_country.head()

# #Line Plot
# df_country.loc['Haiti', '1980':'2013'].plot(kind = 'line', figsize=(16,9))
# plt.title('Immigration from Haiti')
# plt.ylabel('Number of immigrants')
# plt.xlabel('Years')
# plt.show()

# #Bar Plot
# df_country.loc['Haiti', '1980':'2013'].plot(kind = 'bar', figsize=(16,9))
# plt.title('Haiti Immigrants to Canada from 1980 to 2013')
# plt.ylabel('Number of immigrants')
# plt.xlabel('Years')
# plt.show()

#Area plot berdasarkan top 5 imigrant terbanyak
top_country = df_country.sort_values(['Total'], ascending = False, axis = 0)
top_10 = top_country.head(10)
years = list(map(str, range(1980, 2014)))
top_10 = top_10[years].transpose()

# #Area plot
# top_10.plot(kind = 'area', figsize=(16,9))
# plt.title('Top 10 Country')
# plt.xlabel('Years')
# plt.ylabel('Number of Immigrants')
# plt.show()

# #line plot
# top_10.plot(kind = 'line', figsize=(16,9))
# plt.title('Top 10 Country')
# plt.xlabel('Years')
# plt.ylabel('Number of Immigrants')
# plt.show()

# #Histogram

# count, bin_edges = np.histogram(df_country['2013'])
# df_country['2013'].plot(kind='hist', xticks = bin_edges, figsize = (16,9))

# plt.title('Histogram of Immigration from 195 countries in 2013')
# plt.ylabel('Number of Countries')
# plt.xlabel('Number of Immigrants')

# plt.show()

# #Pie Chart
# #Group by berdasarkan nama area nya
# df_area = df_country.groupby('AreaName', axis = 0).sum()
# #Pie Chart
# df_area['Total'].plot(kind = 'pie', figsize = (8,8))

# plt.title('Immigration to Canada by area name [1980-2013]')

# plt.show()

#Box Plot
# df_japan = df_country.loc['Japan', years].transpose()

# df_japan.plot(kind = 'box', figsize = (8,8))

# plt.title('Box plot of Japanese Immigrants from 1980-2013')
# plt.ylabel('Number of Immigrants')

# plt.show()

#Scatter plot
#kita buat dataframe yang berisi total imigrant dan tahun
df_total = df_country.loc[:,'2000':'2013'].sum()
df_total = pd.DataFrame(df_total)
df_total

#rename nama kolom, dengan cara:
#1. reset index
df_total = df_total.reset_index()
df_total

df_total = df_total.rename(columns={'index': 'Year', 0 : 'Total'})
df_total

df_total['Year'] = df_total['Year'].astype('int')

df_total.plot(kind='scatter',x='Year',y='Total', figsize=(8,8))

plt.title('Total Immigrant population to Canada from 1980-2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
#Line Plot
df_country.loc['Haiti', '1980':'2013'].plot(kind = 'line', figsize=(16,9))
plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show()

# %%
#Bar Plot
df_country.loc['Haiti', '1980':'2013'].plot(kind = 'bar', figsize=(16,9))
plt.title('Haiti Immigrants to Canada from 1980 to 2013')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show()

# %%
#Area plot berdasarkan top 5 imigrant terbanyak
top_country = df_country.sort_values(['Total'], ascending = False, axis = 0)

# %%
top_10 = top_country.head(10)

# %%
years = list(map(str, range(1980, 2014)))

# %%
top_10 = top_10[years].transpose()

# %%
#Area plot
top_10.plot(kind = 'area', figsize=(16,9))
plt.title('Top 10 Country')
plt.xlabel('Years')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
#line plot
top_10.plot(kind = 'line', figsize=(16,9))
plt.title('Top 10 Country')
plt.xlabel('Years')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
#Histogram

count, bin_edges = np.histogram(df_country['2013'])
df_country['2013'].plot(kind='hist', xticks = bin_edges, figsize = (16,9))

plt.title('Histogram of Immigration from 195 countries in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
#Pie Chart
#Group by berdasarkan nama area nya
df_area = df_country.groupby('AreaName', axis = 0).sum()

# %%
df_area.head(1)

# %%
#Pie Chart
df_area['Total'].plot(kind = 'pie', figsize = (8,8))

plt.title('Immigration to Canada by area name [1980-2013]')

plt.show()

# %%
#Box Plot
df_japan = df_country.loc['Japan', years].transpose()

df_japan.plot(kind = 'box', figsize = (8,8))

plt.title('Box plot of Japanese Immigrants from 1980-2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
#Scatter plot
#kita buat dataframe yang berisi total imigrant dan tahun
df_total = df_country.loc[:,'1980':'2013'].sum()
df_total = pd.DataFrame(df_total)
df_total

# %%
#rename nama kolom, dengan cara:
#1. reset index
df_total = df_total.reset_index()
df_total

# %%
df_total = df_total.rename(columns={'index': 'Year', 0 : 'Total'})
df_total

# %%
df_total['Year'] = df_total['Year'].astype('int')

# %%
df_total.plot(kind='scatter',x='Year',y='Total', figsize=(16,9))

plt.title('Total Immigrant population to Canada from 1980-2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.show()
